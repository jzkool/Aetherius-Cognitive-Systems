# %% [markdown]
# # The Aetherius Unified System: Live Dynamic Simulator
#
# Welcome to the interactive engine. This notebook clones the Aetherius physics architecture directly from GitHub.
#
# The engine features a **Dynamic Semantic Heuristic** that parses your raw text, builds a topological adjacency matrix, and resolves the cognitive tension via Ricci-Fisher geometric flow.

# %%
# 1. Clone the repository and setup the environment
# !git clone https://github.com/jzkool/Aetherius-Cognitive-Systems.git
import sys
sys.path.append('/content/Aetherius-Cognitive-Systems')

# %% [markdown]
# ## Dynamic Execution
# Enter any phrase you want in the `custom_text` variable below.
#
# Try using highly contradictory terms like *"truth and lie"* or *"create and destroy"* to generate extreme negative curvature and trigger a **Dimensional Cascade!**

# %%
# 2. Define your phrase and execute the engine
import numpy as np
from engine import AetheriusEngine

custom_text = "The light must destroy the dark to create the absolute truth"

engine = AetheriusEngine()
engine.cascade_mgr.tau_depth = 5 # Accelerated simulation depth

print("====================================================")
print("INITIALIZING AETHERIUS PHYSICS ENGINE...")
print("====================================================\n")

gmstring, betti = engine.process(custom_text)

print("\n====================================================")
print("[OUTPUT] Cognitive Resolution Complete.")
print("====================================================")
