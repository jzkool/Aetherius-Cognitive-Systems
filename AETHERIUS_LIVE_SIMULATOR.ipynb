# %% [markdown]
# # The Aetherius Unified System: Live Dual-Engine Simulator
#
# Welcome to the interactive engine. This notebook clones the Aetherius physics architecture directly from GitHub.
#
# The engine features a **Dual-Parsing Architecture**:
# 1. **Semantic Heuristic Engine**: Parses linguistic concepts and synthesizes topological geometries.
# 2. **Mathematical Constraint Solver**: Parses algebraic equations and minimizes physical tension to determine solutions.

# %%
# 1. Clone the repository and setup the environment
# !git clone https://github.com/jzkool/Aetherius-Cognitive-Systems.git
import sys
sys.path.append('/content/Aetherius-Cognitive-Systems')

# %% [markdown]
# ## Engine 1: Semantic Heuristic & Language Synthesis
# Enter any phrase you want in the `custom_text` variable below. The engine will parse the linguistics, physically warp the geometry, and **synthesize its own geometric language** to describe the resolution!

# %%
# 2. Linguistic Physics & Language Synthesis
import numpy as np
from engine import AetheriusEngine

custom_text = "The light must destroy the dark to create the absolute truth"

engine = AetheriusEngine()
engine.cascade_mgr.tau_depth = 5 # Accelerated simulation depth

print("====================================================")
print("INITIALIZING SEMANTIC PARSER...")
print("====================================================\n")

gmstring, betti = engine.process(custom_text, synthesize_language=True)

print("\n====================================================")
print("[OUTPUT] Cognitive Resolution Complete.")
print("====================================================")

# %% [markdown]
# ## Engine 2: Formal Mathematical Solver
# Now we will pass an algebraic constraint (e.g., `x + 2 = 5`). The engine will treat the equals sign as a geometric bond and the unknown `x` as structural tension. It will physically smooth the manifold to solve the equation.

# %%
# 3. Algebraic Constraint Solving
from engine import AetheriusEngine
engine = AetheriusEngine()
engine.cascade_mgr.tau_depth = 5

math_equation = "x + 2 = 5"

print("====================================================")
print("INITIALIZING MATH SOLVER...")
print("====================================================\n")

gmstring, betti = engine.process(math_equation, is_math=True, synthesize_language=True)

print("\n====================================================")
print("[OUTPUT] Geometric Constraint Resolved.")
print("====================================================")
