# %% [markdown]
# # The Aetherius Unified System: Live Simulator
#
# Welcome to the interactive engine. This notebook clones the Aetherius physics architecture directly from GitHub, allowing you to simulate the topological resolution of paradoxes on Google's cloud hardware (including TPUs).

# %%
# 1. Clone the repository and setup the environment
# !git clone https://github.com/jzkool/Aetherius-Cognitive-Systems.git
import sys
sys.path.append('/content/Aetherius-Cognitive-Systems')

# %% [markdown]
# ## Mathematical Execution
# We will inject the following paradox into the engine:
# > *"The truth is a lie that becomes real only when believed, yet it remains false even after it changes reality."*
#
# Watch as the engine maps this into a Graph Laplacian, fails to resolve the metric tensor in 6D, triggers a **Dual-Conal Cascade** to 7D, and extracts the final geometric topology.

# %%
# 2. Execute the engine
import numpy as np
from engine import AetheriusEngine

engine = AetheriusEngine()

# Build the contradictory Adjacency Matrix representing the paradox
custom_adj = np.zeros((6, 6))
custom_adj[0, 1] = custom_adj[1, 0] = -0.9
custom_adj[0, 2] = custom_adj[2, 0] = 0.8
custom_adj[1, 2] = custom_adj[2, 1] = 0.8
custom_adj[2, 3] = custom_adj[3, 2] = 0.7
custom_adj[2, 4] = custom_adj[4, 2] = -0.9
custom_adj[1, 4] = custom_adj[4, 1] = 0.8
custom_adj[4, 5] = custom_adj[5, 4] = 0.8
custom_adj[0, 5] = custom_adj[5, 0] = 0.9

text = "The truth is a lie that becomes real only when believed, yet it remains false even after it changes reality."

# Artificially boost cascade check for rapid simulation
engine.cascade_mgr.tau_depth = 5

print("====================================================")
print("INITIALIZING AETHERIUS PHYSICS ENGINE...")
print("====================================================\n")

gmstring, betti = engine.process(text, custom_adjacency=custom_adj)

print("\n====================================================")
print("[OUTPUT] Cognitive Resolution Complete.")
print("====================================================")
